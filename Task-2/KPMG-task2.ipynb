# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Loading Datasets

# %% [markdown]
# ###### Customer Demographic Dataset

# %%
cust_demo = pd.read_excel("C:/Users/Medha Trust/Desktop/Forage/KPMG/Datasets/Before_preprocessing/CustomerDemographics.xlsx")
cust_demo.columns = cust_demo.iloc[0]
cust_demo = cust_demo[1:]
cust_demo
# Out:
# 0    customer_id      first_name  last_name  gender  \
# 1              1         Laraine  Medendorp       F
# 2              2             Eli    Bockman    Male
# 3              3           Arlin     Dearle    Male
# 4              4          Talbot        NaN    Male
# 5              5  Sheila-kathryn     Calton  Female
# ...          ...             ...        ...     ...
# 3996        3996         Rosalia   Halgarth  Female
# 3997        3997          Blanch     Nisuis  Female
# 3998        3998          Sarene    Woolley       U
# 3999        3999       Patrizius        NaN    Male
# 4000        4000           Kippy    Oldland    Male
#
# 0    past_3_years_bike_related_purchases                  DOB  \
# 1                                     93  1953-10-12 00:00:00
# 2                                     81  1980-12-16 00:00:00
# 3                                     61  1954-01-20 00:00:00
# 4                                     33  1961-10-03 00:00:00
# ...

# %%
cust_demo.gender=cust_demo.gender.replace("F","Female")
cust_demo.gender=cust_demo.gender.replace("Femal","Female")
cust_demo.gender=cust_demo.gender.replace("M","Male")
cust_demo.gender=cust_demo.gender.replace("U","Unknown")

# %% [markdown]
# ###### Customer Address Dataset

# %%
cust_add=pd.read_excel("C:/Users/Medha Trust/Desktop/Forage/KPMG/Datasets/Before_preprocessing/CustomerAddress.xlsx")
cust_add.columns = cust_add.iloc[0]
cust_add = cust_add[1:]
cust_add
# Out:
# 0    customer_id                    address postcode            state  \
# 1              1         060 Morning Avenue     2016  New South Wales
# 2              2        6 Meadow Vale Court     2153  New South Wales
# 3              4         0 Holy Cross Court     4211              QLD
# 4              5        17979 Del Mar Point     2448  New South Wales
# 5              6           9 Oakridge Court     3216              VIC
# ...          ...                        ...      ...              ...
# 3995        3999            1482 Hauk Trail     3064              VIC
# 3996        4000  57042 Village Green Point     4511              QLD
# 3997        4001     87 Crescent Oaks Alley     2756              NSW
# 3998        4002           8194 Lien Street     4032              QLD
# 3999        4003            320 Acker Drive     2251              NSW
#
# 0       country property_valuation
# 1     Australia                 10
# 2     Australia                 10
# ...

# %% [markdown]
# ###### New Costumers Dataset

# %%
new_cust = pd.read_excel("C:/Users/Medha Trust/Desktop/Forage/KPMG/Datasets/Before_preprocessing/NewCustomerList.xlsx")
new_cust.columns = new_cust.iloc[0]
new_cust = new_cust[1:]
new_cust
# Out:
# 0    first_name  last_name  gender past_3_years_bike_related_purchases  \
# 1       Chickie    Brister    Male                                  86
# 2         Morly     Genery    Male                                  69
# 3       Ardelis  Forrester  Female                                  10
# 4        Lucine      Stutt  Female                                  64
# 5       Melinda     Hadlee  Female                                  34
# ...         ...        ...     ...                                 ...
# 996   Ferdinand  Romanetti    Male                                  60
# 997        Burk    Wortley    Male                                  22
# 998    Melloney      Temby  Female                                  17
# 999      Dickie    Cubbini    Male                                  30
# 1000      Sylas    Duffill    Male                                  56
#
# 0                     DOB                     job_title job_industry_category  \
# ...

# %% [markdown]
# ###### Transactions Dataset

# %%
trans = pd.read_excel("C:/Users/Medha Trust/Desktop/Forage/KPMG/Datasets/Before_preprocessing/transactions.xlsx")
trans.columns = trans.iloc[0]
trans = trans[1:]
trans
# Out:
# 0     transaction_id product_id customer_id     transaction_date online_order  \
# 1                  1          2        2950  2017-02-25 00:00:00        False
# 2                  2          3        3120  2017-05-21 00:00:00         True
# 3                  3         37         402  2017-10-16 00:00:00        False
# 4                  4         88        3135  2017-08-31 00:00:00        False
# 5                  5         78         787  2017-10-01 00:00:00         True
# ...              ...        ...         ...                  ...          ...
# 19996          19996         51        1018  2017-06-24 00:00:00         True
# 19997          19997         41         127  2017-11-09 00:00:00         True
# 19998          19998         87        2284  2017-04-14 00:00:00         True
# 19999          19999          6        2764  2017-07-03 00:00:00        False
# 20000          20000         11        1144  2017-09-22 00:00:00         True
#
# ...

# %%
cust_add.columns
# Out:
# Index(['customer_id', 'address', 'postcode', 'state', 'country',
#        'property_valuation'],
#       dtype='object', name=0)

# %%
cust_demo.columns
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'default', 'owns_car', 'tenure'],
#       dtype='object', name=0)

# %%
new_cust.columns
# Out:
# Index([                         'first_name',
#                                  'last_name',
#                                     'gender',
#        'past_3_years_bike_related_purchases',
#                                        'DOB',
#                                  'job_title',
#                      'job_industry_category',
#                             'wealth_segment',
#                         'deceased_indicator',
#                                   'owns_car',
#                                     'tenure',
#                                    'address',
#                                   'postcode',
#                                      'state',
#                                    'country',
#                         'property_valuation',
#                                          nan,
#                                          nan,
#                                          nan,
#                                          nan,
# ...

# %%
trans.columns
# Out:
# Index(['transaction_id', 'product_id', 'customer_id', 'transaction_date',
#        'online_order', 'order_status', 'brand', 'product_line',
#        'product_class', 'product_size', 'list_price', 'standard_cost',
#        'product_first_sold_date'],
#       dtype='object', name=0)

# %%
cust_add.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 1 to 3999
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         3999 non-null   object
#  1   address             3999 non-null   object
#  2   postcode            3999 non-null   object
#  3   state               3999 non-null   object
#  4   country             3999 non-null   object
#  5   property_valuation  3999 non-null   object
# dtypes: object(6)
# memory usage: 187.6+ KB

# %%
cust_add.isna().sum()
# Out:
# 0
# customer_id           0
# address               0
# postcode              0
# state                 0
# country               0
# property_valuation    0
# dtype: int64

# %% [markdown]
# ### Task-1

# %% [markdown]
# #### Data Cleaning on Customer Demographic Data

# %%
cust_demo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 1 to 4000
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          4000 non-null   object
#  1   first_name                           4000 non-null   object
#  2   last_name                            3875 non-null   object
#  3   gender                               4000 non-null   object
#  4   past_3_years_bike_related_purchases  4000 non-null   object
#  5   DOB                                  3913 non-null   object
#  6   job_title                            3494 non-null   object
#  7   job_industry_category                3344 non-null   object
#  8   wealth_segment                       4000 non-null   object
#  9   deceased_indicator                   4000 non-null   object
#  10  default                              3698 non-null   object
# ...

# %%
cust_demo.isna().sum()
# Out:
# 0
# customer_id                              0
# first_name                               0
# last_name                              125
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# job_title                              506
# job_industry_category                  656
# wealth_segment                           0
# deceased_indicator                       0
# default                                302
# owns_car                                 0
# tenure                                  87
# dtype: int64

# %%
cust_demo=cust_demo.drop(["last_name"],axis=1)

# %%
cust_demo.isna().sum()
# Out:
# 0
# customer_id                              0
# first_name                               0
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# job_title                              506
# job_industry_category                  656
# wealth_segment                           0
# deceased_indicator                       0
# default                                302
# owns_car                                 0
# tenure                                  87
# dtype: int64

# %%
cust_demo["DOB"]=cust_demo["DOB"].fillna(cust_demo["DOB"].mode()[0])

# %%
cust_demo["job_title"]=cust_demo["job_title"].fillna(cust_demo["job_title"].mode()[0])

# %%
cust_demo=cust_demo.drop(["default"],axis=1)

# %%
cust_demo["tenure"]=cust_demo["tenure"].fillna(cust_demo["tenure"].mean())

# %%
cust_demo["job_industry_category"]=cust_demo["job_industry_category"].fillna(cust_demo["job_industry_category"].mode()[0])

# %%
cust_demo.isna().sum()
# Out:
# 0
# customer_id                            0
# first_name                             0
# gender                                 0
# past_3_years_bike_related_purchases    0
# DOB                                    0
# job_title                              0
# job_industry_category                  0
# wealth_segment                         0
# deceased_indicator                     0
# owns_car                               0
# tenure                                 0
# dtype: int64

# %%
cust_demo
# Out:
# 0    customer_id      first_name   gender past_3_years_bike_related_purchases  \
# 1              1         Laraine   Female                                  93
# 2              2             Eli     Male                                  81
# 3              3           Arlin     Male                                  61
# 4              4          Talbot     Male                                  33
# 5              5  Sheila-kathryn   Female                                  56
# ...          ...             ...      ...                                 ...
# 3996        3996         Rosalia   Female                                   8
# 3997        3997          Blanch   Female                                  87
# 3998        3998          Sarene  Unknown                                  60
# 3999        3999       Patrizius     Male                                  11
# 4000        4000           Kippy     Male                                  76
#
# ...

# %%
# cust_demo.to_excel("CustomerDemographics(edited).xlsx")

# %% [markdown]
# #### Data Cleaning on Customer Address Data

# %%
cust_add.isna().sum()
# Out:
# 0
# customer_id           0
# address               0
# postcode              0
# state                 0
# country               0
# property_valuation    0
# dtype: int64

# %%
new_cust.columns
# Out:
# Index([                         'first_name',
#                                  'last_name',
#                                     'gender',
#        'past_3_years_bike_related_purchases',
#                                        'DOB',
#                                  'job_title',
#                      'job_industry_category',
#                             'wealth_segment',
#                         'deceased_indicator',
#                                   'owns_car',
#                                     'tenure',
#                                    'address',
#                                   'postcode',
#                                      'state',
#                                    'country',
#                         'property_valuation',
#                                          nan,
#                                          nan,
#                                          nan,
#                                          nan,
# ...

# %%
cust_add
# Out:
# 0    customer_id                    address postcode            state  \
# 1              1         060 Morning Avenue     2016  New South Wales
# 2              2        6 Meadow Vale Court     2153  New South Wales
# 3              4         0 Holy Cross Court     4211              QLD
# 4              5        17979 Del Mar Point     2448  New South Wales
# 5              6           9 Oakridge Court     3216              VIC
# ...          ...                        ...      ...              ...
# 3995        3999            1482 Hauk Trail     3064              VIC
# 3996        4000  57042 Village Green Point     4511              QLD
# 3997        4001     87 Crescent Oaks Alley     2756              NSW
# 3998        4002           8194 Lien Street     4032              QLD
# 3999        4003            320 Acker Drive     2251              NSW
#
# 0       country property_valuation
# 1     Australia                 10
# 2     Australia                 10
# ...

# %%
# cust_add.to_excel("CustomerAddress(edited).xlsx")

# %% [markdown]
# #### Data Cleaning on New Customer List Data

# %%
new_cust=new_cust.drop(new_cust.columns[[16,17,18,19,20]],axis=1)

# %%
new_cust=new_cust.drop("last_name",axis=1)

# %%
new_cust["DOB"]=new_cust["DOB"].fillna(new_cust["DOB"].mode()[0])

# %%
new_cust["job_title"]=new_cust["job_title"].fillna(new_cust["job_title"].mode()[0])
new_cust["job_industry_category"]=new_cust["job_industry_category"].fillna(new_cust["job_industry_category"].mode()[0])

# %%
new_cust.isna().sum()
# Out:
# 0
# first_name                             0
# gender                                 0
# past_3_years_bike_related_purchases    0
# DOB                                    0
# job_title                              0
# job_industry_category                  0
# wealth_segment                         0
# deceased_indicator                     0
# owns_car                               0
# tenure                                 0
# address                                0
# postcode                               0
# state                                  0
# country                                0
# property_valuation                     0
# Rank                                   0
# Value                                  0
# dtype: int64

# %%
new_cust
# Out:
# 0    first_name  gender past_3_years_bike_related_purchases  \
# 1       Chickie    Male                                  86
# 2         Morly    Male                                  69
# 3       Ardelis  Female                                  10
# 4        Lucine  Female                                  64
# 5       Melinda  Female                                  34
# ...         ...     ...                                 ...
# 996   Ferdinand    Male                                  60
# 997        Burk    Male                                  22
# 998    Melloney  Female                                  17
# 999      Dickie    Male                                  30
# 1000      Sylas    Male                                  56
#
# 0                     DOB                     job_title job_industry_category  \
# 1              1957-07-12               General Manager         Manufacturing
# 2              1970-03-22           Structural Engineer              Property
# ...

# %%
# new_cust.to_excel("NewCostumerList(edited).xlsx")

# %% [markdown]
# #### Data Cleaning on Transactions Data

# %%
trans.isna().sum()
# Out:
# 0
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %%
trans["online_order"]=trans["online_order"].fillna("False")

# %%
trans["brand"]=trans["brand"].fillna("others")

# %%
trans.product_line.value_counts()
# Out:
# product_line
# Standard    14176
# Road         3970
# Touring      1234
# Mountain      423
# Name: count, dtype: int64

# %%
trans["product_line"]=trans["product_line"].fillna(trans.product_line.mode()[0])

# %%
trans.product_line.value_counts()
# Out:
# product_line
# Standard    14373
# Road         3970
# Touring      1234
# Mountain      423
# Name: count, dtype: int64

# %%
trans.product_class.value_counts()
# Out:
# product_class
# medium    13826
# high       3013
# low        2964
# Name: count, dtype: int64

# %%
trans.product_class=trans.product_class.fillna(trans.product_class.mode()[0])

# %%
trans.product_size=trans.product_size.fillna("others")

# %%
trans.standard_cost=trans.standard_cost.fillna(trans.standard_cost.mean())

# %%
trans=trans.drop("product_first_sold_date",axis=1)

# %%
trans.isna().sum()
# Out:
# 0
# transaction_id      0
# product_id          0
# customer_id         0
# transaction_date    0
# online_order        0
# order_status        0
# brand               0
# product_line        0
# product_class       0
# product_size        0
# list_price          0
# standard_cost       0
# dtype: int64

# %%
trans
# Out:
# 0     transaction_id product_id customer_id     transaction_date online_order  \
# 1                  1          2        2950  2017-02-25 00:00:00        False
# 2                  2          3        3120  2017-05-21 00:00:00         True
# 3                  3         37         402  2017-10-16 00:00:00        False
# 4                  4         88        3135  2017-08-31 00:00:00        False
# 5                  5         78         787  2017-10-01 00:00:00         True
# ...              ...        ...         ...                  ...          ...
# 19996          19996         51        1018  2017-06-24 00:00:00         True
# 19997          19997         41         127  2017-11-09 00:00:00         True
# 19998          19998         87        2284  2017-04-14 00:00:00         True
# 19999          19999          6        2764  2017-07-03 00:00:00        False
# 20000          20000         11        1144  2017-09-22 00:00:00         True
#
# ...

# %%
# trans.to_excel("transactions(edited).xlsx")

# %% [markdown]
# #### Finding Unique Values in all datasets

# %%
cust_add.customer_id.count()
# Out:
# 3999

# %%
cust_add.customer_id.nunique()
# Out:
# 3999

# %%
cust_demo.customer_id.count()
# Out:
# 4000

# %%
cust_demo.customer_id.nunique()
# Out:
# 4000

# %%
trans.customer_id.count()
# Out:
# 20000

# %%
trans.customer_id.nunique()
# Out:
# 3494

# %% [markdown]
# ##### In this process we have completed data cleaning on all data sets i.e by filling null values with accurate values like mode,mean of columns and filled some revelant columns with others.

# %% [markdown]
# ## Task-2

# %% [markdown]
# #### Data Visualisation

# %%
cust_add
# Out:
# 0    customer_id                    address postcode            state  \
# 1              1         060 Morning Avenue     2016  New South Wales
# 2              2        6 Meadow Vale Court     2153  New South Wales
# 3              4         0 Holy Cross Court     4211              QLD
# 4              5        17979 Del Mar Point     2448  New South Wales
# 5              6           9 Oakridge Court     3216              VIC
# ...          ...                        ...      ...              ...
# 3995        3999            1482 Hauk Trail     3064              VIC
# 3996        4000  57042 Village Green Point     4511              QLD
# 3997        4001     87 Crescent Oaks Alley     2756              NSW
# 3998        4002           8194 Lien Street     4032              QLD
# 3999        4003            320 Acker Drive     2251              NSW
#
# 0       country property_valuation
# 1     Australia                 10
# 2     Australia                 10
# ...

# %%
trans
# Out:
# 0     transaction_id product_id customer_id     transaction_date online_order  \
# 1                  1          2        2950  2017-02-25 00:00:00        False
# 2                  2          3        3120  2017-05-21 00:00:00         True
# 3                  3         37         402  2017-10-16 00:00:00        False
# 4                  4         88        3135  2017-08-31 00:00:00        False
# 5                  5         78         787  2017-10-01 00:00:00         True
# ...              ...        ...         ...                  ...          ...
# 19996          19996         51        1018  2017-06-24 00:00:00         True
# 19997          19997         41         127  2017-11-09 00:00:00         True
# 19998          19998         87        2284  2017-04-14 00:00:00         True
# 19999          19999          6        2764  2017-07-03 00:00:00        False
# 20000          20000         11        1144  2017-09-22 00:00:00         True
#
# ...

# %%
trans1=trans[["transaction_id","product_id","customer_id","transaction_date","brand","product_class"]]
cust_add1=cust_add[["customer_id","state"]]
cust_add1
# Out:
# 0    customer_id            state
# 1              1  New South Wales
# 2              2  New South Wales
# 3              4              QLD
# 4              5  New South Wales
# 5              6              VIC
# ...          ...              ...
# 3995        3999              VIC
# 3996        4000              QLD
# 3997        4001              NSW
# 3998        4002              QLD
# 3999        4003              NSW
#
# [3999 rows x 2 columns]

# %%
trans1=trans1.merge(cust_add1,on="customer_id")
trans1
# Out:
# 0     transaction_id product_id customer_id     transaction_date  \
# 0                  1          2        2950  2017-02-25 00:00:00
# 1              11065          1        2950  2017-10-16 00:00:00
# 2              18923         62        2950  2017-04-26 00:00:00
# 3                  2          3        3120  2017-05-21 00:00:00
# 4               6862          4        3120  2017-10-05 00:00:00
# ...              ...        ...         ...                  ...
# 19963          19854         68         130  2017-02-02 00:00:00
# 19964          17966         17        2789  2017-12-06 00:00:00
# 19965          18462         80        2789  2017-06-20 00:00:00
# 19966          17981         69        3446  2017-12-26 00:00:00
# 19967          18165         86        3446  2017-12-03 00:00:00
#
# 0               brand product_class            state
# 0               Solex        medium              VIC
# 1      Giant Bicycles        medium              VIC
# ...

# %%
# ax1=trans1.state.value_counts().plot.bar(title="State wise customers")
# ax1
# sns.countplot(x="state",data=trans1)

# %%
# trans1["state"].value_counts().plot.bar()

# %%
# crosstabres=pd.crosstab(trans1.state,trans1.brand)
# crosstabres.plot.barh()

# %%
cust_demo1=cust_demo[["customer_id","gender","past_3_years_bike_related_purchases","job_industry_category"]]
cust_demo1
# Out:
# 0    customer_id   gender past_3_years_bike_related_purchases  \
# 1              1   Female                                  93
# 2              2     Male                                  81
# 3              3     Male                                  61
# 4              4     Male                                  33
# 5              5   Female                                  56
# ...          ...      ...                                 ...
# 3996        3996   Female                                   8
# 3997        3997   Female                                  87
# 3998        3998  Unknown                                  60
# 3999        3999     Male                                  11
# 4000        4000     Male                                  76
#
# 0    job_industry_category
# 1                   Health
# 2       Financial Services
# 3                 Property
# 4                       IT
# 5            Manufacturing
# ...                    ...
# ...

# %%
trans1=trans1.merge(cust_demo1,on="customer_id")
trans1
# Out:
# 0     transaction_id product_id customer_id     transaction_date  \
# 0                  1          2        2950  2017-02-25 00:00:00
# 1              11065          1        2950  2017-10-16 00:00:00
# 2              18923         62        2950  2017-04-26 00:00:00
# 3                  2          3        3120  2017-05-21 00:00:00
# 4               6862          4        3120  2017-10-05 00:00:00
# ...              ...        ...         ...                  ...
# 19963          19854         68         130  2017-02-02 00:00:00
# 19964          17966         17        2789  2017-12-06 00:00:00
# 19965          18462         80        2789  2017-06-20 00:00:00
# 19966          17981         69        3446  2017-12-26 00:00:00
# 19967          18165         86        3446  2017-12-03 00:00:00
#
# 0               brand product_class            state  gender  \
# 0               Solex        medium              VIC    Male
# ...

# %%
trans1.state=trans1.state.replace("New South Wales","NSW")
trans1.state=trans1.state.replace("Victoria","VIC")

# %%
trans1.state.value_counts()
# Out:
# state
# NSW    10685
# VIC     5021
# QLD     4262
# Name: count, dtype: int64

# %%
# ax1=trans1.state.value_counts().plot.bar(title="State wise customers")
# ax1
ax1=sns.countplot(x="state",data=trans1)
ax1.set(title="Number of purchases made in every state")
# Out:
# [Text(0.5, 1.0, 'Number of purchases made in every state')]

# %%
ax2=trans1["brand"].value_counts().plot.bar()
ax2.set(title="Number of purchases made per each brand")
# Out:
# [Text(0.5, 1.0, 'Number of purchases made per each brand')]

# %%
crosstabres=pd.crosstab(trans1.state,trans1.brand)
crosstabres.plot.barh()
# Out:
# <Axes: ylabel='state'>

# %%
trans
# Out:
# 0     transaction_id product_id customer_id     transaction_date online_order  \
# 1                  1          2        2950  2017-02-25 00:00:00        False
# 2                  2          3        3120  2017-05-21 00:00:00         True
# 3                  3         37         402  2017-10-16 00:00:00        False
# 4                  4         88        3135  2017-08-31 00:00:00        False
# 5                  5         78         787  2017-10-01 00:00:00         True
# ...              ...        ...         ...                  ...          ...
# 19996          19996         51        1018  2017-06-24 00:00:00         True
# 19997          19997         41         127  2017-11-09 00:00:00         True
# 19998          19998         87        2284  2017-04-14 00:00:00         True
# 19999          19999          6        2764  2017-07-03 00:00:00        False
# 20000          20000         11        1144  2017-09-22 00:00:00         True
#
# ...

# %%
trans1.transaction_date=pd.to_datetime(trans1.transaction_date)

# %%
trans1.dtypes
# Out:
# 0
# transaction_id                                 object
# product_id                                     object
# customer_id                                    object
# transaction_date                       datetime64[ns]
# brand                                          object
# product_class                                  object
# state                                          object
# gender                                         object
# past_3_years_bike_related_purchases            object
# job_industry_category                          object
# dtype: object

# %%
# trans1.index=trans1.transaction_date
# del trans1["transaction_date"]

# %%
trans1
# Out:
# 0     transaction_id product_id customer_id transaction_date           brand  \
# 0                  1          2        2950       2017-02-25           Solex
# 1              11065          1        2950       2017-10-16  Giant Bicycles
# 2              18923         62        2950       2017-04-26           Solex
# 3                  2          3        3120       2017-05-21   Trek Bicycles
# 4               6862          4        3120       2017-10-05  Giant Bicycles
# ...              ...        ...         ...              ...             ...
# 19963          19854         68         130       2017-02-02      OHM Cycles
# 19964          17966         17        2789       2017-12-06           Solex
# 19965          18462         80        2789       2017-06-20      OHM Cycles
# 19966          17981         69        3446       2017-12-26  Giant Bicycles
# 19967          18165         86        3446       2017-12-03      OHM Cycles
#
# ...

# %%
# trans1["customer_id"].value_counts()

# %%
# sns.lineplot(trans1["past_3_years_bike_related_purchases"])

# %%
sns.countplot(x="gender",hue="brand",data=trans1)
plt.title("Gender vs Brand")
# Out:
# Text(0.5, 1.0, 'Gender vs Brand')

# %%
trans1.product_id.nunique()
# Out:
# 101

# %%
sns.countplot(x="job_industry_category",hue="brand",data=trans1)
plt.xticks(rotation=90)
plt.title("Job category vs Brand")
# Out:
# Text(0.5, 1.0, 'Job category vs Brand')

# %%
sns.countplot(x="product_class",hue="brand",data=trans1)
plt.title("Brand vs Product Class")
# Out:
# Text(0.5, 1.0, 'Brand vs Product Class')
